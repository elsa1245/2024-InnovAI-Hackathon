# %% [markdown]
# # Installs

# %%
# %%time

from IPython.display import clear_output
# !pip install langchain-community==0.2.15 langchain-chroma==0.1.3 langchain-text-splitters==0.2.2 langchain-huggingface==0.0.3 langchain-groq==0.1.9 unstructured==0.15.0 unstructured[pdf]==0.15.0 nltk==3.8.1
clear_output()
# Out:
# CPU times: user 607 ms, sys: 149 ms, total: 757 ms
# Wall time: 56.2 s

# %%
# !pip install pytesseract
# !pip install pymupdf pdfplumber
clear_output()

# %% [markdown]
# # Imports

# %%
import warnings
warnings.filterwarnings("ignore")
import os

from langchain_community.document_loaders import UnstructuredPDFLoader, DirectoryLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA

# %% [markdown]
# # Groq API

# %%
GROQ_API_KEY = "yours):""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"

# %%
os.environ["GROQ_API_KEY"] = GROQ_API_KEY

# %% [markdown]
# # Load documents

# %%
directory_path = "/content/"

loader = DirectoryLoader(directory_path, glob="./*.pdf", loader_cls=UnstructuredPDFLoader)
documents = loader.load()

print(f"Nombre de documents chargés : {len(documents)}")
# Out:
# Nombre de documents chargés : 4

# %% [markdown]
# # Split documents

# %%
# %%time
text_splitter = CharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=500
)

text_chunks = text_splitter.split_documents(documents)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 2517, which is longer than the specified 2000
# WARNING:langchain_text_splitters.base:Created a chunk of size 3135, which is longer than the specified 2000
# WARNING:langchain_text_splitters.base:Created a chunk of size 2614, which is longer than the specified 2000
# CPU times: user 17.5 ms, sys: 1.04 ms, total: 18.5 ms
# Wall time: 19.4 ms

# %%
persist_directory = "doc_db"

# %%
from IPython.display import clear_output

embedding = HuggingFaceEmbeddings()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Create Embeddings

# %%
vectorstore = Chroma.from_documents(
    documents=text_chunks,
    embedding=embedding,
    persist_directory=persist_directory
)

# %%
retriever = vectorstore.as_retriever()

# %% [markdown]
# # Model

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)

# %% [markdown]
# # Test

# %%
query = " What are the main constraints faced by farmers in adopting drip irrigation?"
response = qa_chain.invoke({"query":query})

# %%
print(response)
# Out:
# {'query': ' What are the main constraints faced by farmers in adopting drip irrigation?', 'result': 'According to the provided information, the main constraints faced by farmers in adopting drip irrigation are:\n\n1. Non-availability of quality material\n2. No follow-up services by drip agencies\n3. High initial investment cost\n4. Lack of capital to cover maximum holding under drip irrigation\n5. Delay in sanction of loan\n6. Leakage in the present drip system', 'source_documents': [Document(metadata={'source': '/content/df1.pdf'}, page_content='Collected information were analysed and results are presented in the following table.\n\nTable 1. Benefits of drip irrigation\n\nS.\n\nBenefits of Drip irrigation farmers\n\nNo. expressing the advantages\n\nNo.\n\nNumber\n\nPer cent\n\n(n= 30)\n\n(%)\n\n1.\n\nSaving of water\n\n28\n\n93.33\n\n2.\n\nSaving of labour cost for irrigation\n\n22\n\n73.33\n\n3.\n\nUniform application\n\n27\n\n90.00\n\n4.\n\nImproved quality of produce\n\n20\n\n66.67\n\n5.\n\nEasy method of irrigation\n\n26\n\n86.67\n\n6.\n\nDecreased weed growth\n\n21\n\n70.00\n\n7.\n\nIncreased crop yield\n\n23\n\n76.67\n\nMultiple responses possible\n\nThe above table revealed that majority of the respondents opined that saving of water (93.33 %) is\n\nmajor benefit of drip irrigation and followed by Uniform application (90.00 %), Easy method of\n\nirrigation (86.67 %), Increased crop yield(76.67 %), Saving of labour cost for irrigation(73.33 %),\n\nDecreased weed growth(70.00%) and Improved quality of produce (66.67 %).\n\nConstraints encountered by the drip irrigation growers\n\nThe constraints encountered by the farmers had possessed the problem of non-availability\n\nof quality material, no follow up services by drip agencies, high initial investment cost, lack of\n\ncapital to cover maximum holding under drip irrigation and delay in sanction of loan, leakage in\n\nthe present drip system\n\nConclusion\n\nThe Benefits encountered by the farmers are saving of water, uniform application and easy method\n\nof irrigation and the constraints are problem of non-availability of quality material and no follow\n\nup services by drip agencies. It is clear from the study that the drip irrigation agencies, financing\n\ninstitutions and others to supply adequate standard spare parts and other appropriate measures to\n\nensure the satisfactory situation for proper adoption of drip irrigation method.\n\nReference:\n\nKandaswamy. P., 1990. Drip irrigation need for more scientific research for large scale adoption.\n\nKisan World, 17: 31-32.'), Document(metadata={'source': '/content/df1.pdf'}, page_content='up services by drip agencies. It is clear from the study that the drip irrigation agencies, financing\n\ninstitutions and others to supply adequate standard spare parts and other appropriate measures to\n\nensure the satisfactory situation for proper adoption of drip irrigation method.\n\nReference:\n\nKandaswamy. P., 1990. Drip irrigation need for more scientific research for large scale adoption.\n\nKisan World, 17: 31-32.\n\nPatil, S. M., 1990. Drip irrigation very successful in Banana too. Kisan World, 17: 28-29.\n\nShivakumar, H. K., Ramachandrappa, B. K., Nanjappa, H. V .and Roopadevi, V. D., 2001. Micro\n\nirrigation macro future. Agro India, 5: 18-19.'), Document(metadata={'source': '/content/df2.pdf'}, page_content='30.\n\n"The History of the Drip Irrigation System and What is Available Now ". www.irrigation.learnabout.info.\n\n31. "Jain Irrigation". www.JainsUSA.com. Retrieved 19 December 2017.\n\n32. Molden, D., Oweis, T., Steduto, P., Bindraban, P., Hanjra, M.A., Kijne, J., Improv- ing agricultural water\n\nproductivity: between optimism and caution. Agric. Water Manage. 2010; 97, 528–535.\n\n33.\n\nIST, 2013. Avaliac ̧ ambient strategies dos novas investment EFMA relatives’ à Reed Secondary de Rega,\n\nno ambit do INALENTEJO (Strategic Environmental Assessment of new EFMA’s Investments). In: Relatório\n\npreliminary: R ...

# %%
print(response["result"])
# Out:
# According to the provided information, the main constraints faced by farmers in adopting drip irrigation are:
#
# 1. Non-availability of quality material
# 2. No follow-up services by drip agencies
# 3. High initial investment cost
# 4. Lack of capital to cover maximum holding under drip irrigation
# 5. Delay in sanction of loan
# 6. Leakage in the present drip system

# %%
query = "How does the non-availability of quality materials affect drip irrigation adoption?"
response = qa_chain.invoke({"query":query})
print(response["result"])
# Out:
# According to the provided text, the non-availability of quality materials is one of the constraints encountered by the farmers who adopt drip irrigation. This constraint can affect drip irrigation adoption in several ways:
#
# 1. **Inadequate performance**: Low-quality materials can lead to poor performance of the drip irrigation system, resulting in reduced water application efficiency, uneven water distribution, and decreased crop yields.
# 2. **Increased maintenance**: Substandard materials may require more frequent maintenance, repairs, or replacement, which can be time-consuming and costly for farmers.
# 3. **Reduced system lifespan**: Poor-quality materials can lead to a shorter lifespan of the drip irrigation system, requiring farmers to invest in new equipment more frequently.
# 4. **Increased risk of clogging**: Low-quality drippers or emitters can clog more easily, reducing the system's efficiency and effectiveness.
# 5. **Decreased farmer confidence**: The non-availability of quality materials can erode farmer confidence in the drip irrigation system, making them less likely to adopt or continue using it.
#
# To address this constraint, drip irrigation agencies, financing institutions, and other stakeholders should ensure that adequate standard spare parts and other necessary measures are available to farmers, enabling them to adopt and maintain the drip irrigation method effectively.

# %% [markdown]
# # Evaluation

# %%
query = "What is the capital of France?"
generated_answer = "The capital of France is Paris."
chunk = "Paris, the capital of France, is known for its art, fashion, and culture."

# %%
evaluation_prompt = f"""
Please evaluate the following response based on these criteria:
1. **Relevance**: Does the answer directly address the question?
2. **Coherence**: Is the answer logically structured and internally consistent?
3. **Accuracy**: Is the answer factually correct based on the context?
4. **Clarity**: Is the answer well-formulated and easy to understand?

**Question**: {query}
**Generated Answer**: {generated_answer}
**Supporting Chunk**: {chunk}

Provide a score from 1 (very poor) to 10 (excellent) for each criterion and explain your score.
"""

# %%
from langchain_groq import ChatGroq

# Initialize ChatGroq model
model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# Send evaluation prompt to model, passing the prompt directly as a string.
response = model.invoke(evaluation_prompt) # Changed from {"query": evaluation_prompt} to evaluation_prompt

# Print the evaluation results
# Access the 'content' attribute of the AIMessage object instead of using indexing.
print(response.content)
# Out:
# Here's the evaluation of the response based on the given criteria:
#
# 1. **Relevance**: 10/10
# The answer directly addresses the question, providing the correct information about the capital of France.
#
# 2. **Coherence**: 9/10
# The answer is logically structured and internally consistent. However, the supporting chunk seems unrelated to the main answer and could be removed without affecting the coherence of the response.
#
# 3. **Accuracy**: 10/10
# The answer is factually correct based on the context. Paris is indeed the capital of France.
#
# 4. **Clarity**: 9/10
# The answer is well-formulated and easy to understand. However, the supporting chunk could be considered unnecessary and might make the response slightly less clear by adding an unrelated piece of information.
#
# Overall, the response is strong, with high scores in relevance, accuracy, and clarity. The coherence score could be improved by removing the supporting chunk or making it more relevant to the main answer.

# %%
import json

# Load the JSON file containing queries and expected answers
with open("/content/test.json", "r") as file:
    data = json.load(file)

# Initialize your model (ChatGroq in this case)
model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# Function to evaluate answers based on the queries and chunks
def evaluate_responses(data):
    for item in data['data']:
        query = item['query']
        expected_answer = item['expected_answer']
        chunk = item['chunk']

        # Prepare the prompt for the model
        evaluation_prompt = f"""
        Please evaluate the following response based on these criteria:
        1. **Relevance**: Does the answer directly address the question?
        2. **Coherence**: Is the answer logically structured and internally consistent?
        3. **Accuracy**: Is the answer factually correct based on the context?
        4. **Clarity**: Is the answer well-formulated and easy to understand?

        **Question**: {query}
        **Generated Answer**: {expected_answer}
        **Supporting Chunk**: {chunk}

        Provide a score from 1 (very poor) to 10 (excellent) for each criterion and explain your score.
        """

        # Send the evaluation request to the model
        response = model.invoke(evaluation_prompt)

        # Print out the evaluation result
        print(f"Evaluation for Query: {query}")
        print(response.content)
        print("-" * 80)

# Evaluate the responses in the loaded data
evaluate_responses(data)
# Out:
# Evaluation for Query: Who wrote *Don Quixote*?
# **Relevance: 10**
# The answer directly addresses the question, providing the name of the author of *Don Quixote*. The supporting chunk further reinforces this answer by providing additional context about the author.
#
# **Coherence: 9**
# The answer is logically structured and internally consistent. However, the supporting chunk could be more integrated with the answer, rather than being a separate statement. A more coherent approach would be to include the additional context within the answer itself.
#
# **Accuracy: 10**
# The answer is factually correct. Miguel de Cervantes is widely recognized as the author of *Don Quixote*. The supporting chunk also provides accurate information about the author.
#
# **Clarity: 9**
# The answer is well-formulated and easy to understand. However, the supporting chunk could be more concise and directly related to the answer. A more clear approach would be to integrate the supporting chunk into the answer, making it a single, cohesive statement.
#
# Overall, the answer is strong, but could benefit from a more integrated and concise approach to the supporting chunk.
# --------------------------------------------------------------------------------
# Evaluation for Query: What is the capital of France?
# **Relevance: 10**
# The answer directly addresses the question, providing the name of the capital of France. It is a straightforward and accurate response to the query.
#
# **Coherence: 9**
# The answer is logically structured, providing a clear and concise response. However, the supporting chunk, while informative, is not directly related to the question and could be considered a tangential piece of information. A more coherent response might integrate the supporting chunk more closely with the main answer.
#
# **Accuracy: 10**
# The answer is factually correct, as Paris is indeed the capital of France.
#
# **Clarity: 9**
# The answer is well-formulated and easy to understand, but the supporting chunk could be considered a separate piece of information that is not directly related to the question. A more clear response might integrate the supporting chunk more closely with the main answer or provide it as a separate piece of information.
# --------------------------------------------------------------------------------
# Evaluation for Query: When did the French Revolution start?
# **Relevance: 9**
# The answer directly addresses the question by providing a specific date (1789) for when the French Revolution started. However, it would be even more relevant if the answer included a brief explanation or context, but the supporting chunk provides additional information that helps clarify the answer.
#
# **Coherence: 8**
# The answer is logically structured, as it provides a single date (1789) as the starting point of the French Revolution. However, the supporting chunk seems to be a separate entity, and it would be more coherent if it were integrated into the main answer or if the answer provided more context about why 1789 is significant.
#
# **Accuracy: 10**
# The answer is factually correct based on the context. The French Revolution did indeed begin in 1789, and the storming of the Bastille is a significant event that marked the start of the revolution.
#
# **Clarity: 8**
# The answer is well-formulated and easy to understand, but it could be improved by providing more context or explanation. The supporting chunk helps clarify the answer, but it would be more effective if it were integrated into the main answer or if the answer provided more background information about the French Revolution.
#
# Overall, the answer is strong, but it could benefit from additional context and explanation to make it more comprehensive and effective.
# --------------------------------------------------------------------------------
# Evaluation for Query: What is the largest planet in our solar system?
# **Relevance: 10**
# The answer directly addresses the question, providing the name of the largest planet in our solar system. The supporting chunk further clarifies the answer by providing additional information about Jupiter's size.
#
# **Coherence: 9**
# The answer is logically structured, with the main answer being a single word ("Jupiter") and the supporting chunk providing additional context. However, the supporting chunk could be more integrated into the main answer, rather than being a separate chunk.
#
# **Accuracy: 10**
# The answer is factually correct based on the context. Jupiter is widely recognized as the largest planet in our solar system, and the supporting chunk provides a specific measurement to support this claim.
#
# **Clarity: 9**
# The answer is well-formulated and easy to understand, with the main answer being a clear and concise response to the question. However, the supporting chunk could be more clearly linked to the main answer, and the use of a specific measurement (diameter) might be more relevant to some readers than others.
# --------------------------------------------------------------------------------
# Evaluation for Query: What is a neural network?
# **Relevance: 8**
# The answer directly addresses the question by defining what a neural network is. However, it could be more comprehensive, as the question might be looking for a more detailed explanation. The supporting chunk provides additional context but doesn't directly address the question.
#
# **Coherence: 9**
# The answer is logically structured and easy to understand. It provides a clear definition of a neural network. The supporting chunk is also coherent and provides additional information, but it's not directly related to the question.
#
# **Accuracy: 9**
# The answer is factually correct. Neural networks are indeed designed to recognize patterns, and they mimic the way a human brain operates to process data. However, the answer could be more accurate if it included more details about the architecture and functionality of neural networks.
#
# **Clarity: 9**
# The answer is well-formulated and easy to understand. The language is simple and concise, making it accessible to a wide range of audiences. The supporting chunk is also clear, but it could be more relevant to the question.
#
# Overall, the answer is good, but it could be improved by providing more details and making the supporting chunk more relevant to the question.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Save and Export the Model

# %%
"""import json

# First, get the necessary attributes of the model you want to save
model_config = {
    "model": model.model_name,  # Changed from model.model to model.model_name
    # Add other relevant attributes like temperature, etc. if needed
    "temperature": model.temperature
}

# Then, save the configuration as a JSON file:
with open("./saved_model_config.json", "w") as file:
    json.dump(model_config, file)

print("Model configuration saved successfully.")

# To reload the model:
with open("./saved_model_config.json", "r") as file:
    model_config = json.load(file)

# Create a new instance of ChatGroq using the saved configuration:
reloaded_model = ChatGroq(**model_config)  # ** unpacks the dictionary into keyword arguments
# Out:
# Model configuration saved successfully.

# %%
import shutil

shutil.make_archive("/content/doc_db", 'zip', "/content/doc_db")
print("Dossier compressé avec succès en /content/doc_db.zip")
# Out:
# Dossier compressé avec succès en /content/doc_db.zip

# %%
# !pip install flask ngrok
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (3.0.3)
# Collecting ngrok
#   Downloading ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Downloading ngrok-1.4.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 56.1 MB/s eta 0:00:00
# Installing collected packages: ngrok
# Successfully installed ngrok-1.4.0

# %%
from flask import Flask, request, jsonify
from threading import Thread
import time

app = Flask(__name__)

# Exemple de modèle de RAG (vous pouvez utiliser votre propre modèle ici)
def mock_qa_chain(query):
    # Cette fonction est une simulation d'une réponse générée par le modèle
    return {"result": f"Réponse à la question : {query}"}

@app.route("/ask", methods=["POST"])
def ask():
    # Récupérer la question envoyée par l'utilisateur
    query = request.json["query"]
    result = qa_chain(query)  # Remplacez cette ligne par votre modèle RAG
    return jsonify({"response": result["result"]})  # Ne retourne que la réponse

# Lancer l'application Flask dans un thread séparé
def run_app():
    app.run(host="0.0.0.0", port=5001)  # Changez ici le port de 5000 à 5001

thread = Thread(target=run_app)
thread.start()



# Attendre que l'application Flask démarre
time.sleep(5)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.28.0.12:5001
# INFO:werkzeug:Press CTRL+C to quit

# %%
from pyngrok import ngrok

# Ouvrir un tunnel ngrok sur le port 5001
public_url = ngrok.connect(5001)

# Afficher l'URL publique générée par ngrok
print(f"Votre API est maintenant accessible à l'adresse : {public_url}")
# Out:
# Votre API est maintenant accessible à l'adresse : NgrokTunnel: "https://34a5-34-147-79-96.ngrok-free.app" -> "http://localhost:5001"

# %%
import requests

# L'URL publique générée par ngrok
url = "http://34a5-34-147-79-96.ngrok-free.app/ask"

# La question à poser
query = {"query": "What drip irrigation?"}

# Envoyer la requête POST à l'API Flask
response = requests.post(url, json=query)

# Afficher la réponse de l'API
print(response.json())
# Out:
# INFO:werkzeug:127.0.0.1 - - [01/Dec/2024 04:09:27] "POST /ask HTTP/1.1" 200 -
# {'response': 'According to the provided information, the main constraints faced by farmers in adopting drip irrigation are:\n\n1. Non-availability of quality material\n2. No follow-up services by drip agencies\n3. High initial investment cost\n4. Lack of capital to cover maximum holding under drip irrigation\n5. Delay in sanction of loan\n6. Leakage in the present drip system'}
